# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %matplotlib inline
pd.set_option('display.notebook_repr_html', False)

# %%
x = np.random.random_integers(1, 10, size=40)
y = np.random.random_integers(1, 10, size=40)
size = np.random.random_integers(1, 50, size=40)**2

# %%
x, y, size
# Out:
# (array([ 5,  9,  7,  4,  3,  8,  2,  1,  7,  9,  2,  7,  6,  7,  2,  5, 10,
#          6,  4,  2,  2,  9,  6, 10,  2,  1,  3,  5,  8,  6,  4,  9,  1, 10,
#          1,  3,  1,  5,  2,  6]),
#  array([ 7,  3,  2,  8,  3,  8,  7,  7, 10,  3,  4,  6,  5,  7,  7,  1,  4,
#         10, 10,  7,  8,  5,  5,  4,  4, 10, 10,  4,  6,  3,  4,  6,  5,  3,
#          6, 10, 10,  2,  7,  6]),
#  array([ 484, 2304, 1024,  361,   25, 1849,  961, 2500,    1, 1024,  529,
#          841,  225,   49, 1369, 1296, 1369, 1764,  784, 1681,   36,    1,
#           36,  841, 1764,  841,  484,  169,  841,  100,  256, 1849,    1,
#          841,  625,  961, 1521,  196,    9, 1681]))

# %%
df = pd.DataFrame({'kolom1': x, 'kolom2': y, 'kolom3' : size})

# %% [markdown]
# ### Scatter plot (Matplotlib)

# %%
plt.scatter(df.kolom1, df.kolom2, df.kolom3, alpha=0.5)
plt.grid()
plt.title('Matplotlib Scatter')

# %% [markdown]
# ### Scatter plot (Pandas) --> Wrapper for Matplotlib

# %%
df.plot(kind='scatter', x='kolom1', y='kolom2', s=df.kolom3, title='Pandas Scatter', alpha=0.5)
